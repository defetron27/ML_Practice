# %%
# https://www.english-learn-online.com/vocabulary/electronic-devices/learn-electronic-devices-vocabulary-in-english/
# https://www.wordstream.com/popular-keywords/jewlery-keywords
# https://www.macmillandictionary.com/thesaurus-category/british/types-of-jewellery
# https://whatsag.com/mobile-technology/what-are-the-types-of-gaming-apps.php
# https://towardsdatascience.com/custom-named-entity-recognition-using-spacy-7140ebbb3718
# how to create custom text classification model
# https://towardsdatascience.com/introducing-custom-classifier-build-your-own-text-classification-model-without-any-training-data-40254d37e13d
# https://monkeylearn.com/blog/how-to-create-text-classifiers-machine-learning/
# https://towardsdatascience.com/creating-a-custom-classifier-for-text-cleaning-a2a1fc818935
# https://stackoverflow.com/questions/18837262/convert-python-dict-into-a-dataframe
# train and predict text with spacy
# https://www.machinelearningplus.com/nlp/custom-text-classification-spacy/#:~:text=Text%20Classification%20is%20the%20process,convenient%20through%20the%20textcat%20component.&text=Training%20Custom%20Text%20Classification%20Model%20in%20spaCy.

# %%
document.getElementsByTagName("divleft")
document.getElementsByClassName("divleft")
var p = document.getElementsByClassName("divleft")[1].getElementsByTagName("li")
var arr = []; for(var i=0; i<p.length; i++){ arr[i] = p[i].innerText }
arr
["smart phone", "digital camera", "video camera", "camcorder", "fax machine", "calculator", "monitor", "keyboard", "printer", "speaker", "laptop", "tablet", "coffee maker", "iron", "lantern", "MP3 player", "sewing machine", "flash drive", "USB drive", "webcam", "screen", "remote control", "memory card", "scale", "dish washer"]
copy(arr)

# %%
document.getElementsByClassName("thes-ref-title")[0].innerText
"anklet"
var arr = document.getElementsByClassName("thes-ref-title")
undefined
var p = []
undefined
for(var i=0; i<arr.length; i++) { p[i] = arr[i].innerText }

# %%
document.getElementsByClassName(" clear"
document.getElementsByClassName(" clear")[0]
document.getElementsByClassName(" clear")[0].getElementsByTagName("h2")
var arr = document.getElementsByClassName(" clear")[0].getElementsByTagName("h2")
var p =[]
for(var i=0; i<arr.length; i++) { p[i] = arr[i].innerText }
p
["Betting Apps", "Adventure Gaming Apps", "Arcade Gaming Apps", "Role-Playing Games or RPG", "Puzzle Gaming Apps", "Multiplayer Online Battle Arena Gaming Apps (MOBA)", "Card Gaming Apps", "Strategy Gaming Apps"]

# %%
# !pip install black
# Out:
# ...
#      |████████████████████████████████| 1.1MB 5.2MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 727kB 18.4MB/s
# ...
#      |████████████████████████████████| 747kB 30.4MB/s
# ...
#   Created wheel for black: filename=black-20.8b1-cp37-none-any.whl size=124184 sha256=d995b50b998d0efd1e310d150a85e847f79fb27d3f4aca7dcc5c7e738be43d03
#   Stored in directory: /root/.cache/pip/wheels/6e/10/b5/edf7359c2edd0305cce7e3f96e07daf7ce55dceac9d3ce3373
# Successfully built black
# ...
#   Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
# ...

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

# %%
lst = [
    'electronic',
    'device',
    'refrigerator',
    'fridge',
    'deep freezer',
    'microwave oven',
    'washing machine',
    'dryer',
    'stove',
    'oven',
    'vacuum cleaner',
    'mixer',
    'toaster',
    'food processor',
    'iron',
    'fan',
    'air conditioner',
    'heater',
    'humidifier',
    'hair dryer',
    'electric razor',
    'television',
    'radio',
    'telephone',
    'cell phone',
    "smart phone",
    "digital camera",
    "video camera",
    "camcorder",
    "fax machine",
    "calculator",
    "monitor",
    "keyboard",
    "printer",
    "speaker",
    "laptop",
    "tablet",
    "coffee maker",
    "iron",
    "lantern",
    "MP3 player",
    "sewing machine",
    "flash drive",
    "USB drive",
    "webcam",
    "screen",
    "remote control",
    "memory card",
    "scale",
    "dish washer"
    ]

# %%
lst = ["anklet", "band", "bangle", "bracelet", "brooch", "cameo", "choker", "circlet", "clip", "costume jewellery", "diadem", "earring", "engagement ring", "locket", "medallion", "necklace", "nosering", "pendant", "pin", "ring", "sleeper", "stickpin", "stud", "tiara", "tiepin", "tie tack", "wedding band", "wedding ring"]

# %%
lst = ["Action and Adventure", "Classics", "Comic Book or Graphic Novel", "Detective and Mystery", "Fantasy", "Historical Fiction", "Horror", "Literary Fiction", "Romance", "Science Fiction (Sci-Fi)", "Short Stories", "Suspense and Thrillers", "Women's Fiction"]

# %%
lst = ["Blues", "Jazz", "Rhythm and Blues", "Rock and Roll", "Rock", "Country", "Soul", "Dance", "Hip Hop"]

# %%
eletronics_lst = ["electronic", "device", "refrigerator", "fridge", "deep freezer", "microwave oven", "washing machine", "dryer", "stove", "oven", "vacuum cleaner", "mixer", "toaster", "food processor", "iron", "fan", "air conditioner", "heater", "humidifier", "hair dryer", "electric razor", "television", "radio", "telephone", "cell phone", "smart phone", "digital camera", "video camera", "camcorder", "fax machine", "calculator", "monitor", "keyboard", "printer", "speaker", "laptop", "tablet", "coffee maker", "iron", "lantern", "MP3 player", "sewing machine", "flash drive", "USB drive", "webcam", "screen", "remote control", "memory card", "scale", "dish washer"]
eletronics_lst
# Out:
# ['electronic',
#  'device',
#  'refrigerator',
#  'fridge',
#  'deep freezer',
#  'microwave oven',
#  'washing machine',
#  'dryer',
#  'stove',
#  'oven',
#  'vacuum cleaner',
#  'mixer',
#  'toaster',
#  'food processor',
#  'iron',
#  'fan',
#  'air conditioner',
#  'heater',
#  'humidifier',
#  'hair dryer',
#  'electric razor',
#  'television',
#  'radio',
#  'telephone',
#  'cell phone',
#  'smart phone',
#  'digital camera',
#  'video camera',
#  'camcorder',
#  'fax machine',
#  'calculator',
#  'monitor',
#  'keyboard',
#  'printer',
#  'speaker',
#  'laptop',
#  'tablet',
#  'coffee maker',
#  'iron',
#  'lantern',
#  'MP3 player',
#  'sewing machine',
#  'flash drive',
#  'USB drive',
#  'webcam',
#  'screen',
#  'remote control',
#  'memory card',
#  'scale',
#  'dish washer']

# %%
jewellery_lst = ["anklet", "band", "bangle", "bracelet", "brooch", "cameo", "choker", "circlet", "clip", "costume jewellery", "diadem", "earring", "engagement ring", "locket", "medallion", "necklace", "nosering", "pendant", "pin", "ring", "sleeper", "stickpin", "stud", "tiara", "tiepin", "tie tack", "wedding band", "wedding ring"]
jewellery_lst
# Out:
# ['anklet',
#  'band',
#  'bangle',
#  'bracelet',
#  'brooch',
#  'cameo',
#  'choker',
#  'circlet',
#  'clip',
#  'costume jewellery',
#  'diadem',
#  'earring',
#  'engagement ring',
#  'locket',
#  'medallion',
#  'necklace',
#  'nosering',
#  'pendant',
#  'pin',
#  'ring',
#  'sleeper',
#  'stickpin',
#  'stud',
#  'tiara',
#  'tiepin',
#  'tie tack',
#  'wedding band',
#  'wedding ring']

# %%
books_lst = ["Action and Adventure", "Classics", "Comic Book or Graphic Novel", "Detective and Mystery", "Fantasy", "Historical Fiction", "Horror", "Literary Fiction", "Romance", "Science Fiction (Sci-Fi)", "Short Stories", "Suspense and Thrillers", "Women's Fiction"]

# %%
music_lst = ["Blues", "Jazz", "Rhythm and Blues", "Rock and Roll", "Rock", "Country", "Soul", "Dance", "Hip Hop"]

# %%
def list_lower(lst):
  return [i.lower() for i in lst]

# %%
list_lower(eletronics_lst)
# Out:
# ['electronic',
#  'device',
#  'refrigerator',
#  'fridge',
#  'deep freezer',
#  'microwave oven',
#  'washing machine',
#  'dryer',
#  'stove',
#  'oven',
#  'vacuum cleaner',
#  'mixer',
#  'toaster',
#  'food processor',
#  'iron',
#  'fan',
#  'air conditioner',
#  'heater',
#  'humidifier',
#  'hair dryer',
#  'electric razor',
#  'television',
#  'radio',
#  'telephone',
#  'cell phone',
#  'smart phone',
#  'digital camera',
#  'video camera',
#  'camcorder',
#  'fax machine',
#  'calculator',
#  'monitor',
#  'keyboard',
#  'printer',
#  'speaker',
#  'laptop',
#  'tablet',
#  'coffee maker',
#  'iron',
#  'lantern',
#  'mp3 player',
#  'sewing machine',
#  'flash drive',
#  'usb drive',
#  'webcam',
#  'screen',
#  'remote control',
#  'memory card',
#  'scale',
#  'dish washer']

# %%
eletronics_lst = list_lower(eletronics_lst)
jewellery_lst = list_lower(jewellery_lst)
books_lst = list_lower(books_lst)
music_lst = list_lower(music_lst)

# %%
data = {"electronics": eletronics_lst, "jewellery": jewellery_lst, "books": books_lst, "music": music_lst}

data["books"]
# Out:
# ['action and adventure',
#  'classics',
#  'comic book or graphic novel',
#  'detective and mystery',
#  'fantasy',
#  'historical fiction',
#  'horror',
#  'literary fiction',
#  'romance',
#  'science fiction (sci-fi)',
#  'short stories',
#  'suspense and thrillers',
#  "women's fiction"]

# %%
data_0 = {}

for i,j in data.items():
  for k in j:
    if i == "electronics":
      data_0[k] = "electronics"
    elif i == "jewellery":
      data_0[k] = "jewellery"
    elif i == "books":
      data_0[k] = "books"
    elif i == "music":
      data_0[k] = "music"

data_0
# Out:
# {'action and adventure': 'books',
#  'air conditioner': 'electronics',
#  'anklet': 'jewellery',
#  'band': 'jewellery',
#  'bangle': 'jewellery',
#  'blues': 'music',
#  'bracelet': 'jewellery',
#  'brooch': 'jewellery',
#  'calculator': 'electronics',
#  'camcorder': 'electronics',
#  'cameo': 'jewellery',
#  'cell phone': 'electronics',
#  'choker': 'jewellery',
#  'circlet': 'jewellery',
#  'classics': 'books',
#  'clip': 'jewellery',
#  'coffee maker': 'electronics',
#  'comic book or graphic novel': 'books',
#  'costume jewellery': 'jewellery',
#  'country': 'music',
#  'dance': 'music',
#  'deep freezer': 'electronics',
#  'detective and mystery': 'books',
#  'device': 'electronics',
#  'diadem': 'jewellery',
#  'digital camera': 'electronics',
#  'dish washer': 'electronics',
#  'dryer': 'electronics',
#  'earring': 'jewellery',
#  'electric razor': 'electronics',
#  'electronic': 'electronics',
#  'engagement ring': 'jewellery',
#  'fan': 'electronics',
# ...

# %%
import pandas as pd

df = pd.DataFrame(data_0.items(), columns=["sub_category", "category"])

# %%
df
# Out:
#     sub_category     category
# 0     electronic  electronics
# 1         device  electronics
# 2   refrigerator  electronics
# 3         fridge  electronics
# 4   deep freezer  electronics
# ..           ...          ...
# 94          rock        music
# 95       country        music
# 96          soul        music
# 97         dance        music
# 98       hip hop        music
#
# [99 rows x 2 columns]

# %%
data_0.items()
# Out:
# dict_items([('electronic', 'electronics'), ('device', 'electronics'), ('refrigerator', 'electronics'), ('fridge', 'electronics'), ('deep freezer', 'electronics'), ('microwave oven', 'electronics'), ('washing machine', 'electronics'), ('dryer', 'electronics'), ('stove', 'electronics'), ('oven', 'electronics'), ('vacuum cleaner', 'electronics'), ('mixer', 'electronics'), ('toaster', 'electronics'), ('food processor', 'electronics'), ('iron', 'electronics'), ('fan', 'electronics'), ('air conditioner', 'electronics'), ('heater', 'electronics'), ('humidifier', 'electronics'), ('hair dryer', 'electronics'), ('electric razor', 'electronics'), ('television', 'electronics'), ('radio', 'electronics'), ('telephone', 'electronics'), ('cell phone', 'electronics'), ('smart phone', 'electronics'), ('digital camera', 'electronics'), ('video camera', 'electronics'), ('camcorder', 'electronics'), ('fax machine', 'electronics'), ('calculator', 'electronics'), ('monitor', 'electronics'), ('keyboard', 'e
# ...

# %%
from sklearn.utils import shuffle
df = shuffle(df)
df.reindex()
# Out:
#    sub_category     category
# 69      sleeper    jewellery
# 47        scale  electronics
# 91         jazz        music
# 30   calculator  electronics
# 21   television  electronics
# ..          ...          ...
# 48  dish washer  electronics
# 33      printer  electronics
# 83       horror        books
# 23    telephone  electronics
# 63    medallion    jewellery
#
# [99 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
import re
from collections import Counter

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.33, random_state=42)

# %%
fig = plt.figure(figsize=(8,4))
sns.barplot(x = train['category'].unique(), y=train['category'].value_counts())
plt.show()

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
punctuations = string.punctuation
def cleanup_text(docs, logging=False):
    texts = []
    counter = 1
    for doc in docs:
        if counter % 1000 == 0 and logging:
            print("Processed %d out of %d documents." % (counter, len(docs)))
        counter += 1
        doc = nlp(doc, disable=['parser', 'ner'])
        tokens = [tok.lemma_.lower().strip() for tok in doc if tok.lemma_ != '-PRON-']
        tokens = [tok for tok in tokens if tok not in stopwords and tok not in punctuations]
        tokens = ' '.join(tokens)
        texts.append(tokens)
    return pd.Series(texts)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.metrics import accuracy_score
import string
import re
import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
SYMBOLS = " ".join(string.punctuation).split(" ") + ["-", "...", "”", "”"]
class CleanTextTransformer(TransformerMixin):
   def transform(self, X, **transform_params):
        return [cleanText(text) for text in X]
   def fit(self, X, y=None, **fit_params):
        return self
def get_params(self, deep=True):
        return {}
    
def cleanText(text):
    text = text.strip().replace("\n", " ").replace("\r", " ")
    text = text.lower()
    return text
def tokenizeText(sample):
    tokens = parser(sample)
    lemmas = []
    for tok in tokens:
        lemmas.append(tok.lemma_.lower().strip() if tok.lemma_ != "-PRON-" else tok.lower_)
    tokens = lemmas
    tokens = [tok for tok in tokens if tok not in SYMBOLS]
    return tokens

# %%
def printNMostInformative(vectorizer, clf, N):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    topClass1 = coefs_with_fns[:N]
    topClass2 = coefs_with_fns[:-(N + 1):-1]
    print("Class 1 best: ")
    for feat in topClass1:
        print(feat)
    print("Class 2 best: ")
    for feat in topClass2:
        print(feat)
vectorizer = CountVectorizer(tokenizer=tokenizeText, ngram_range=(1,1))
clf = LinearSVC()

pipe = Pipeline([('cleanText', CleanTextTransformer()), ('vectorizer', vectorizer), ('clf', clf)])
# data
train1 = train['sub_category'].tolist()
labelsTrain1 = train['category'].tolist()
test1 = test['sub_category'].tolist()
labelsTest1 = test['category'].tolist()
# train
pipe.fit(train1, labelsTrain1)
# test
preds = pipe.predict(test1)
print("accuracy:", accuracy_score(labelsTest1, preds))
print("Top 10 features used to predict: ")

printNMostInformative(vectorizer, clf, 10)
pipe = Pipeline([('cleanText', CleanTextTransformer()), ('vectorizer', vectorizer)])
transform = pipe.fit_transform(train1, labelsTrain1)
vocab = vectorizer.get_feature_names()
for i in range(len(train1)):
    s = ""
    indexIntoVocab = transform.indices[transform.indptr[i]:transform.indptr[i+1]]
    numOccurences = transform.data[transform.indptr[i]:transform.indptr[i+1]]
    for idx, num in zip(indexIntoVocab, numOccurences):
        s += str((vocab[idx], num))
# Out:
# accuracy: 0.6060606060606061
# Top 10 features used to predict:
# Class 1 best:
# (-0.4023337692263709, 'rock')
# (-0.4023337692263709, 'roll')
# (-0.16083382956447323, 'ring')
# (-0.15358920701153167, 'band')
# (-0.1434495058572296, 'scale')
# (-0.14344874665278168, 'webcam')
# (-0.14344845959000332, 'pendant')
# (-0.14344790376837788, 'fan')
# (-0.1434478936441804, 'pin')
# (-0.14344776360557146, 'device')
# Class 2 best:
# (1.1898868190607563, 'fantasy')
# (1.1898854305385138, 'romance')
# (1.1898851475435737, 'horror')
# (0.7906630784977677, 'and')
# (0.7260317793251563, 'fiction')
# (0.7139331393303079, 'stories')
# (0.7139331393303079, 'short')
# (0.42351826805432574, 'women')
# (0.42351826805432574, "'s")
# (0.3976664539931187, 'adventure')

# %%
from sklearn import metrics
print(metrics.classification_report(labelsTest1, preds, 
                                    target_names=df['category'].unique()))
# Out:
#               precision    recall  f1-score   support
#
#    jewellery       1.00      0.50      0.67         4
#  electronics       0.57      1.00      0.72        17
#        music       0.00      0.00      0.00         9
#        books       1.00      0.33      0.50         3
#
#     accuracy                           0.61        33
#    macro avg       0.64      0.46      0.47        33
# weighted avg       0.50      0.61      0.50        33
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
